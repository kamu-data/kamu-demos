# %%
# %load_ext kamu
# %import_dataset matches

# %%
# %%sql -o df
# select stats_json
# from matches
# # where match_id = 'FE48264646657D56C5AEA4BDA79EC265'

# %%
# %%local
# import carball
# import matplotlib.pyplot as plt
# import json
# import pandas as pd
# import time
# import numpy as np
# from scipy.stats import kde
# import os
# from carball.json_parser.game import Game
# from carball.analysis.analysis_manager import AnalysisManager
# from os import path
#
# analysis = carball.analyze_replay_file("6F2A80BC4197946E058672A658C10069.replay")
# with open('game4.json', 'w') as fo:
#     analysis.write_json_out_to_file(fo)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [5], line 13
#      10 from carball.analysis.analysis_manager import AnalysisManager
#      11 from os import path
# ---> 13 analysis = carball.analyze_replay_file("6F2A80BC4197946E058672A658C10069.replay")
#      14 with open('game4.json', 'w') as fo:
#      15     analysis.write_json_out_to_file(fo)
#
# File /opt/conda/lib/python3.10/site-packages/carball/decompile_replays.py:48, in analyze_replay_file(replay_path, controls, sanity_check, analysis_per_goal, logging_level, calculate_intensive_events, clean)
#      45 if logging_level != logging.NOTSET:
#      46     logging.getLogger('carball').setLevel(logging_level)
# ---> 48 _json = decompile_replay(replay_path)
#      49 game = Game()
#      50 game.initialize(loaded_json=_json)
#
# File /opt/conda/lib/python3.10/site-packages/carball/decompile_replays.py:21, in decompile_replay(replay_path)
#      14 def decompile_replay(replay_path):
#      15     """
#      16     Takes a path to the replay and outputs the json of that replay.
#      17
#      18     :param replay_path: Path to a specific replay.
#      19     :return: The object created from boxcars.
#      20     """
# ---> 21     with open(replay_path, 'rb') as f:
#      22         buf = f.read()
#      23     return parse_replay(buf)
#
# FileNotFoundError: [Errno 2] No such file or directory: '6F2A80BC4197946E058672A658C10069.replay'

# %%
# %%local
# import carball
# import matplotlib.pyplot as plt
# import json
# import pandas as pd
# import time
# import numpy as np
# from scipy.stats import gaussian_kde as kde
# import os
# from carball.json_parser.game import Game
# from carball.analysis.analysis_manager import AnalysisManager
# from os import path
# # from tabulate import tabulate
# path_to_json=""
#
# bgoalsx,bgoalsy,ogoalsx,ogoalsy = [],[],[],[]
# json_files = [pos_json for pos_json in os.listdir("/opt/workdir/") if pos_json.endswith('.json')]
# blue, orange = [],[]
# playernam = ["KrabbyPattie","visper"]
# #playernam = ["1","2","3"]
# playerids = []
# datatype = ["boostUsage","numLargeBoosts","numSmallBoosts","timeFullBoost","timeNoBoost","averageSpeed","timeAtSlowSpeed","timeAtSuperSonic"]
# playerdata = {}
# best_data = {}
# dat = []
# for k in playernam:
#     playerdata[k] = []
# for i in datatype:
#     best_data[i] = []
# # print(best_data)
# for index, file in enumerate(json_files):
#     with open(path_to_json+file,"r") as fo:
#         data = json.load(fo)
#     if index == 0:
#         for x in data["players"]:
#             if x["name"] == playernam:
#                 playerids.append(x["id"]["id"])
#     if index == len(json_files)-1:
#         for x in data["players"]:
#             for k in playernam:
#                 if x["name"] == k:
#                     s = x["stats"]["speed"]
#                     a = x["stats"]["averages"]
#                     b = x["stats"]["boost"]
#                     playerdata[k].append(b["boostUsage"])
#                     playerdata[k].append(b["numLargeBoosts"])
#                     playerdata[k].append(b["numSmallBoosts"])
#                     playerdata[k].append(b["timeFullBoost"])
#                     playerdata[k].append(b["timeNoBoost"])
#                     playerdata[k].append(a["averageSpeed"])
#                     playerdata[k].append(s["timeAtSlowSpeed"])
#                     playerdata[k].append(s["timeAtSuperSonic"])
#     for j in data["players"]:
#         s = j["stats"]["speed"]
#         a = j["stats"]["averages"]
#         b = j["stats"]["boost"]
#         for i,k in enumerate(datatype):
#             if i < 5:
#                 try:
#                     best_data[k].append(b[k])
#                 except:
#                     best_data[k].append(0)
#             elif i < 6:
#                 try:
#                     best_data[k].append(a[k])
#                 except:
#                     best_data[k].append(0)
#             else:
#                 try:
#                     best_data[k].append(s[k])
#                 except:
#                     best_data[k].append(0)
#
#
#     for x in data["gameStats"]["hits"]:
#         if "goal" in x:
#             # if x["playerId"]["id"] in playerids:
#             bgoalsx.append(x["ballData"]["posX"])
#             bgoalsy.append(x["ballData"]["posY"])
#
# for i,k in enumerate(best_data):
#     if i == 4 or i == 6:
#         dat.append(min(best_data[k]))
#     else:
#         dat.append(max(best_data[k]))
#
# # print(dat)
# goals = np.array([bgoalsx,bgoalsy])
# k = kde(goals)
# pmin=-5140
# pmax=5140
# step=80
# xi, yi = np.mgrid[pmin:pmax:step,pmin:pmax:step]
# zi = k(np.vstack([xi.flatten(), yi.flatten()]))
#
# # collabel = [playernam[0],playernam[1],playernam[2],"best stats"]
# collabel = [playernam,"best stats"]
#
# g = pd.DataFrame(playerdata, index=datatype)
# g["best"] = dat
# print(g)
#
# fig, axs = plt.subplot_mosaic("AABB;AACC")
# img = plt.imread("resources/simple-pitch.png")
#
# axs["A"].pcolormesh(xi, yi, zi.reshape(xi.shape), shading="gouraud", cmap="magma")
# axs["A"].set_label("Heatmap of where goals were scored from")
#
# axs["B"].axis("off")
#
#
# extent = axs["A"].get_window_extent().transformed(fig.dpi_scale_trans.inverted())
#
# axs["C"].axis("off")
#
#
#
#
#
# # table = axs["B"].table(cellText=g.values,colLabels=collabel,rowLabels=datatype,loc="center")
# # print(tabulate(table))
#
#
# # extent = axs["B"].get_window_extent().transformed(fig.dpi_scale_trans.inverted())
# # fig.savefig("table.png",bbox_inches=extent.expanded(2.25,1),dpi=600)
# # table.auto_set_font_size(False)
# # table.set_fontsize(12)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import carball
#       2 import matplotlib.pyplot as plt
#       3 import json
#
# ModuleNotFoundError: No module named 'carball'
